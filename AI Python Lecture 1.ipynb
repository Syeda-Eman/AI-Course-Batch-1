# %% [markdown]
# # **Hope to Skill-Free AI course**

# %% [markdown]
# ## **Python Lecture- 1**

# %% [markdown]
# ### **1- Naming Variables**

# %%
num_students = 25

# %%
sales_today = 125.78

# %%
student_name = "Eman"

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(num_students)
print('num_students')
# Out:
# 25
# num_students

# %%
print(sales_today)
# Out:
# 125.78

# %%
print(student_name)
# Out:
# Eman

# %% [markdown]
# ### **Things to avoid when assigning variables**
#
# 1. Dont use numbers(e.g. 1,2,3)
# 2. Dont use special characters(e.g. @,-, #)
# 3. Dont use reserved keywords(e.g. if, else, print)
#
# (These conditions are applied in some cases not everywhere)

# %%
# Invalid variable name starting with a number
2nd_student = "Huda"
# Out:
#   File "<ipython-input-8-80f7c9dcec25>", line 2
#     2nd_student = "Huda"
#     ^
# SyntaxError: invalid decimal literal

# %%
# Invalid variable name with a hyphen
total-sales = 35.98

# %%
# Invalid variable name using a reserved keyword
else = 267

# %% [markdown]
# ### **2- Data Types**
#
# **In programming, data types specify the type of data that can be stored in a variable.**

# %% [markdown]
# 23 is assigned to the variable "num" which means the data type of num is integer (int).

# %%
num = 23

# %%
num

# %% [markdown]
# Hope to Skills free AI course is assigned to the variable "course" which means the data type of course is string (str).

# %%
course = "Hope to Skills free AI course"

# %%
course

# %% [markdown]
# 35.51 is assigned to the variable "score" which means the data type of score is (float).

# %%
score = 35.51

# %%
score

# %% [markdown]
# 1+2j is assigned to the variable "complex_num" which means the data type of complex_num is (complex).

# %%
complex_number = 1+2j

# %%
complex_number

# %% [markdown]
# ### **3- Operators**
# 1. (+) addition
# 2. (-) subtraction
# 3. / division
# 4. ** exponentiation
# 5. % modulus (remainder after division)
# 6. Comparison Operators are discussed Later
# 7. Python has incorporated operators like += but, ++ and -- do not work in Python.

# %%
#Addition
2+2

# %%
#Subtraction
2-2

# %%
#Multiplication
2*2

# %%
#Division
2/2

# %%
#Reminder
3%2

# %%
#Quotient
2//2

# %%
#You can also try adding, subtracting, multiplicating, and dividing like this:
num1 = 5
num2 = 3
ans = num1 + num2
print(ans)

# %% [markdown]
# ## **Some tasks relvant to the topic**

# %%
# Simple program to calculate the area of rectangle

length = 2.5
height = 3.5
area = length * height
print(area)
# Out:
# 8.75

# %%
#Creating a simple python program to swap variables using three variable.

a = 30
b = 25
c = a

a = b
b = c

print(a,b)
# Out:
# 25 30

# %%
#Creating a simple python program to swap variable using only two variables
a = 50
b = 45

a, b = b, a

print(a,b)
# Out:
# 45 50
